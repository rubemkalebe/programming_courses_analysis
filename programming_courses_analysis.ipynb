# %%
import plotly.plotly as py
from bokeh.models import ColumnDataSource
from bokeh.io import output_notebook, show
from bokeh.plotting import figure
from bokeh.models import HoverTool, NumeralTickFormatter
from bokeh.layouts import gridplot
from bokeh.charts import Bar,output_file, Scatter, BoxPlot
# Import necessary module
from sqlalchemy import create_engine
import pandas as pd

# %%
# Create engine: engine
engine = create_engine('sqlite:///programming.sqlite')

# %%
# What are the tables in the database?

# Save the table names to a list: table_names
table_names  = engine.table_names()

# Print the table names to the shell
print(table_names)

# See the data model here: http://chinookdatabase.codeplex.com/wikipage?title=Chinook_Schema&referringTitle=Home
# Out:
# ['Grade']

# %%
# The power of SQL lies in relationships between tables: INNER JOIN

# Execute query and store records in DataFrame: df
data = pd.read_sql_query("select * from Grade",engine)

# drop the unnecessary column
data = data.drop('index', 1)

# print the number of unique students
print(len(data['Aluno_ID'].unique()))

# Print head of DataFrame
data.head()
# Out:
# 766
#    Aluno_ID  Período                                         Disciplina  \
# 0         0   2014.1  IMD0012.0 - INTRODUÇĂO ŔS TÉCNICAS DE PROGRAMAÇĂO
# 1         1   2014.1  IMD0012.0 - INTRODUÇĂO ŔS TÉCNICAS DE PROGRAMAÇĂO
# 2         2   2014.1  IMD0012.0 - INTRODUÇĂO ŔS TÉCNICAS DE PROGRAMAÇĂO
# 3         3   2014.1  IMD0012.0 - INTRODUÇĂO ŔS TÉCNICAS DE PROGRAMAÇĂO
# 4         4   2014.1  IMD0012.0 - INTRODUÇĂO ŔS TÉCNICAS DE PROGRAMAÇĂO
#
#    Situaçăo  Média Final  Unidade I  Unidade II   Unidade III
# 0  APROVADO          7.0        4.9          9.0          7.0
# 1  APROVADO          7.3        8.0          7.0          7.0
# 2  APROVADO          9.3        9.5          8.3         10.0
# 3  APROVADO          7.3        6.5          7.0          8.3
# 4  APROVADO          7.5        5.5          8.0          9.0

# %%
df = pd.read_sql_query("SELECT distinct Disciplina from Grade", engine)

df
# Out:
#                                           Disciplina
# 0  IMD0012.0 - INTRODUÇĂO ŔS TÉCNICAS DE PROGRAMAÇĂO
# 1    IMD0012.1 - PRÁTICAS DE TÉCNICAS DE PROGRAMAÇĂO
# 2             IMD0029 - ESTRUTURA DE DADOS BÁSICAS I
# 3               IMD0030 - LINGUAGEM DE PROGRAMAÇĂO I
# 4           IMD0039 - ESTRUTURAS DE DADOS BÁSICAS II
# 5              IMD0040 - LINGUAGEM DE PROGRAMAÇĂO II

# %%
edb1_notas = {}
edb2_notas = {}

def retrieve_edb2_info(aid):
    tmp2 = pd.read_sql_query('''
            SELECT Aluno_ID, [Média Final]
            FROM Grade
            WHERE Aluno_ID = ''' + str(aid) + '''
                AND Disciplina = "IMD0039 - ESTRUTURAS DE DADOS BÁSICAS II"
            LIMIT 1;''', engine
    )
    if tmp2.empty != True:
        try:
            media_edb2 = float(tmp2['Média Final'])
            return media_edb2
        except TypeError:
            return 0.0
    return None

# Execute query and store records in DataFrame: df
data_edb1_edb2 = pd.read_sql_query('''SELECT Aluno_ID, [Média Final]
                       FROM Grade
                       WHERE [Média Final] >= 7.0
                           AND Disciplina = "IMD0029 - ESTRUTURA DE DADOS BÁSICAS I"''',
                       engine)

# print the number of unique students
#print(len(df['Aluno_ID'].unique()))
for aid, med in zip(data_edb1_edb2['Aluno_ID'], data_edb1_edb2['Média Final']):
    edb2 = retrieve_edb2_info(aid)
    if edb2 != None:
        edb1_notas[int(aid)] = float(med)
        edb2_notas[int(aid)] = float(edb2)

# %%
red_edb1 = []
red_edb2 = []
green_edb1 = []
green_edb2 = []
blue_edb1 = []
blue_edb2 = []

for x in sorted(edb1_notas.keys()):
    if edb2_notas[int(x)] < 5.0:
        red_edb1.append(edb1_notas[x])
        red_edb2.append(edb2_notas[int(x)])
    elif edb2_notas[int(x)] >= 5.0 and edb2_notas[int(x)] < 7.0:
        green_edb1.append(edb1_notas[x])
        green_edb2.append(edb2_notas[int(x)])
    elif edb2_notas[int(x)] >= 7.0:
        blue_edb1.append(edb1_notas[x])
        blue_edb2.append(edb2_notas[int(x)])

# %% [markdown]
# ## Análise 4 - Situação dos alunos que foram bem em EDBI
#
# Nesta seção utilizamos a média em EDB2 dos alunos que foram aprovados em EDBI com média $\geq 7,0$, para avaliar se os alunos que foram bem em EDBI também foram bem em EBD2. No gráfico apresentado, o eixo X representa as médias em EDB2 (variando assim de 0 à 10) e o eixo Y representa as médias em EDBI (variando assim de 7 à 10). Sendo assim, um ponto neste gráfico é um par ordenado $(média\_edb1, média\_itp)$ que refere-se à um aluno que cursou EDBI, foi aprovado com média $\geq 7.0$ e pagou a disciplina de EDB2 no semestre seguinte. Esta análise é apresentada de duas formas (através de gráfico de dispersão e gráfico de setores) e é útil para avaliar se os alunos com bom desempenho na disciplina anterior continuavam a apresentar bom desempenho na disciplina seguinte. Nos dois gráficos os alunos estão agrupados de acordo com as cores vermelho ($média\_edb1 \lt 5,0$), verde ($5,0 \leq média\_edb1 \lt 7,0$) e azul ($média\_edb1 \gt 7,0$).
#
# O gráfico de dispersão nos mostra em detalhes o desempenho em EDB2 daqueles que foram aprovados em EDBI. A partir da dispersão dos pontos percebemos que os alunos que foram aprovados com $média \geq 7,0$ em EDB1 tiveram um desempenho muito bom em EDB2, com um total de aproximadamente $50\%$ da turma.
#
# Podemos ver também, que o número de reprovados corresponde a apenas $12.9\%$ do total de alunos, e cerca de $37\%$ dos alunos com média $5,0 \leq média\_edb1 \lt 7,0$, mostrando que $87\%$ dos que vão bem em EDB1, conseguem ser aprovados em EDB2.
#
# O gráfico de setores resume esses resultados de cada uma das categorias.
#
# A partir disso concluímos que é importante e útil aproveitar a disciplina de EDB1 para conseguir aproveitar a disciplina seguinte, que é EDB2.

# %%
p = figure(plot_width = 900, plot_height = 500, x_axis_label = 'Média em EDB2', y_axis_label = 'Média em EDB I',
           title = 'Desempenho dos alunos que cursaram EDB1 e EDB2 em seguida')

p.circle(x = red_edb2, y = red_edb1, color = "red", size = 7)
p.circle(x = green_edb2, y = green_edb1, color = "green", size = 7)
p.circle(x = blue_edb2, y = blue_edb1, color = "blue", size = 7)

print('Vermelho: ' + str(len(red_edb2)))
print('Verde: ' + str(len(green_edb2)))
print('Azul: ' + str(len(blue_edb2)))

# Load data from dataframes into figure object
labels = 'Média < 5.0', '5.0 <= Média < 7.0', 'Média >= 7.0'
sizes = [len(red_edb2), len(green_edb2), len(blue_edb2)]
fig = {
    'data': [
        {
            'labels': labels,
            'values': sizes,
            'marker': {'colors': ['red', 'green', 'blue']},
            'type': 'pie',
            'name': 'notas',
            'domain': {'x': [.20, 1]},
            'hoverinfo':'label+percent+name+value',
            'textposition': 'outside',
            'hole': '.4'
        },
        
    ],
    'layout':{
        'title': 'Média Final em EDB II dos alunos que tiveram média final em EDB I acima de 7',
        'annotations':[
                {
                    'font': {'size': 20},
                    'showarrow': False,
                    'text': 'Situação',
                    'x': 0.6,
                    'y': 0.5
                }
        ]
    }
}


output_notebook()
show(p)
# Out:
# Vermelho: 11
# Verde: 32
# Azul: 42
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="972a36db-e5ac-4579-865f-625e5cbb53cd">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c3a1175d-de33-453e-928e-d8b2c076b91f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("c3a1175d-de33-453e-928e-d8b2c076b91f").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c3a1175d-de33-453e-928e-d8b2c076b91f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c3a1175d-de33-453e-928e-d8b2c076b91f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"eff750da-809a-42de-9dd1-3319c5ff8be2":{"roots":{"references":[{"attributes":{"plot":{"id":"45150d3a-d416-4761-bb51-89715d3792ce","subtype":"Figure","type":"Plot"}},"id":"f9588d38-b7d9-4241-9309-a10fd95961ff","type":"HelpTool"},{"attributes":{"data_source":{"id":"7779b0db-4846-409c-9c3b-fdf735a72615","type":"ColumnDataSource"},"glyph":{"id":"74755520-cdec-4fb1-a9a2-92ae04e2264a","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"c56a1c84-3957-4d63-92d9-4fc26fd95259","type":"Circle"},"selection_glyph":null},"id":"d0c593ee-2d30-418f-9180-fc9d8c5fde13","type":"GlyphRenderer"},{"attributes":{"axis_label":"M\u00e9dia em EDB2","formatter":{"id":"991612cf-bec0-4da5-b719-46e1c2eb9d45","type":"BasicTickFormatter"},"plot":{"id":"45150d3a-d416-4761-bb51-89715d3792ce","subtype":"Figure","type":"Plot"},"ticker":{"id":"ef06df7d-b49c-4416-b434-41cb8b87a5f2","type":"BasicTicker"}},"id":"dca148d9-b677-4427-b448-289839b5a0f3","type":"LinearAxis"},{"attributes":{},"id":"ef06df7d-b49c-4416-b434-41cb8b87a5f2","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0.7,3.4,0.0,1.3,0.0,0.8,1.7,0.5,2.7,0.0,1.2],"y":[7.7,7.9,8.2,7.2,8.2,7.4,7.0,7.3,7.5,7.5,7.9]}},"id":"7779b0db-4846-409c-9c3b-fdf735a72615","type":"ColumnDataSource"},{"attributes":{"axis_label":"M\u00e9dia em EDB I","formatter":{"id":"ac6339c4-31fd-4e68-a7c4-af75bfbc259c","type":"BasicTickFormatter"},"plot":{"id":"45150d3a-d416-4761-bb51-89715d3792ce","subtype":"Figure","type":"Plot"},"ticker":{"id":"a5d72213-04d7-4bac-bfdd-731f09fd9705","type":"BasicTicker"}},"id":"c4fd8867-8fa8-4cfc-a576-07756f31b26b","type":"LinearAxis"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"8900fa87-6bd3-485f-9384-2d851cb6e915","type":"BoxAnnotation"},{"attributes":{},"id":"ac6339c4-31fd-4e68-a7c4-af75bfbc259c","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"45150d3a-d416-4761-bb51-89715d3792ce","subtype":"Figure","type":"Plot"},"ticker":{"id":"ef06df7d-b49c-4416-b434-41cb8b87a5f2","type":"BasicTicker"}},"id":"c223b2cc-b271-45be-b523-8ac4b4c2e8bb","type":"Grid"},{"attributes":{"dimension":1,"plot":{"id":"45150d3a-d416-4761-bb51-89715d3792ce","subtype":"Figure","type":"Plot"},"ticker":{"id":"a5d72213-04d7-4bac-bfdd-731f09fd9705","type":"BasicTicker"}},"id":"aff44499-9b4b-45a1-aea1-d0028c6f7b44","type":"Grid"},{"attributes":{},"id":"a5d72213-04d7-4bac-bfdd-731f09fd9705","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[9.3,9.8,7.6,7.8,7.6,9.0,7.1,10.0,8.8,9.8,7.4,7.2,9.6,7.5,8.9,9.1,7.7,8.7,8.6,7.6,8.2,10.0,7.4,9.0,9.4,8.5,10.0,10.0,8.5,7.6,8.6,9.3,7.6,7.8,9.2,8.0,8.7,9.0,8.0,9.4,7.2,10.0],"y":[7.4,9.1,7.2,7.3,8.4,8.1,7.6,9.5,7.9,8.4,8.4,7.3,9.6,7.8,8.8,8.3,9.0,8.0,8.1,8.2,8.8,9.7,9.3,8.2,8.1,9.0,9.5,8.6,7.0,7.7,8.3,8.4,7.7,8.0,7.7,7.0,7.6,7.8,8.3,9.3,8.4,7.1]}},"id":"2e0dfba1-5ec1-4dbc-a120-37e261f3e9cf","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"45150d3a-d416-4761-bb51-89715d3792ce","subtype":"Figure","type":"Plot"}},"id":"8e98ea39-bb52-42d7-b2bb-9b6067c99c89","type":"ResetTool"},{"attributes":{"plot":{"id":"45150d3a-d416-4761-bb51-89715d3792ce","subtype":"Figure","type":"Plot"}},"id":"3dfb7d2d-02cf-4f5a-941a-c1a6a3e84cb4","type":"SaveTool"},{"attributes":{},"id":"991612cf-bec0-4da5-b719-46e1c2eb9d45","type":"BasicTickFormatter"},{"attributes":{"fill_color":{"value":"red"},"line_color":{"value":"red"},"size":{"units":"screen","value":7},"x":{"field":"x"},"y":{"field":"y"}},"id":"74755520-cdec-4fb1-a9a2-92ae04e2264a","type":"Circle"},{"attributes":{"overlay":{"id":"8900fa87-6bd3-485f-9384-2d851cb6e915","type":"BoxAnnotation"},"plot":{"id":"45150d3a-d416-4761-bb51-89715d3792ce","subtype":"Figure", ...

# %%
# Plot pie charts
py.iplot(fig)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~matryus/102.embed" height="525px" width="100%"></iframe>

# %%
data_rep = pd.read_sql_query('''SELECT Aluno_ID, Período, Disciplina
                       FROM Grade
                       WHERE Situaçăo = "REPROVADO"''',
                       engine)
data_rep.head()
# Out:
#    Aluno_ID  Período                                         Disciplina
# 0        28   2014.1  IMD0012.0 - INTRODUÇĂO ŔS TÉCNICAS DE PROGRAMAÇĂO
# 1        29   2014.1  IMD0012.0 - INTRODUÇĂO ŔS TÉCNICAS DE PROGRAMAÇĂO
# 2        30   2014.1  IMD0012.0 - INTRODUÇĂO ŔS TÉCNICAS DE PROGRAMAÇĂO
# 3        31   2014.1  IMD0012.0 - INTRODUÇĂO ŔS TÉCNICAS DE PROGRAMAÇĂO
# 4        32   2014.1  IMD0012.0 - INTRODUÇĂO ŔS TÉCNICAS DE PROGRAMAÇĂO

# %%
data_rep['count'] = 0
data_rep = pd.DataFrame(data_rep.groupby(['Disciplina','Período'])['count'].count()).reset_index()
data_rep.head()
# Out:
#                                           Disciplina  Período  count
# 0  IMD0012.0 - INTRODUÇĂO ŔS TÉCNICAS DE PROGRAMAÇĂO   2014.1     13
# 1  IMD0012.0 - INTRODUÇĂO ŔS TÉCNICAS DE PROGRAMAÇĂO   2014.2     18
# 2  IMD0012.0 - INTRODUÇĂO ŔS TÉCNICAS DE PROGRAMAÇĂO   2015.1      6
# 3  IMD0012.0 - INTRODUÇĂO ŔS TÉCNICAS DE PROGRAMAÇĂO   2015.2     29
# 4  IMD0012.0 - INTRODUÇĂO ŔS TÉCNICAS DE PROGRAMAÇĂO   2016.1     20

# %% [markdown]
# ## Análise 1 - Número de Reprovados x Disciplina em todos os anos.
#
# Nesta seção utilizamos os dados do número de reprovados em cada uma das disciplinas disponíveis, em todos os anos.
#
# Como podemos ver abaixo,as disciplinas Introdução às Técnicas de Programação (ITP) e Práticas de Técnicas de Programação(PTP), Estruturas de dados Básicas I (EDBI) e Laboratório de Programação I(LPI), talvez por serem disciplinas iniciais e primeiros contatos dos alunos com programação, possuem um número de reprovações bem elevado em relação a EDBII e LP2, acumulando aproximadamente 100 reprovações no total.

# %%
TOOLS = 'box_zoom,box_select,crosshair,resize,reset,wheel_zoom, pan'
Bar_Reprovados = Bar(data_rep, 'Disciplina', values='count',color = 'Disciplina', xlabel="Disciplina",  
         ylabel = "Nº de Reprovados", title="Disciplinas pelo Nº de Reprovados", 
         legend = False,tools=[TOOLS])

output_notebook()
show(Bar_Reprovados)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="c229fe12-b934-4672-a5ba-ebabdde6eac2">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f69f7ec6-9bc8-4a24-a621-75f5a2aecf93"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("f69f7ec6-9bc8-4a24-a621-75f5a2aecf93").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f69f7ec6-9bc8-4a24-a621-75f5a2aecf93");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f69f7ec6-9bc8-4a24-a621-75f5a2aecf93' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c38dd8af-533f-43eb-999a-4880c517092e":{"roots":{"references":[{"attributes":{"below":[{"id":"961c4751-5b70-4e09-af93-36ad34ba201e","type":"CategoricalAxis"}],"css_classes":null,"left":[{"id":"f8296dd8-3265-4964-859b-4dd818a95ea5","type":"LinearAxis"}],"renderers":[{"id":"3c870678-6972-419d-b815-b024ae062d8d","type":"BoxAnnotation"},{"id":"71f616b0-f2fd-420a-b2aa-796edebd159f","type":"BoxAnnotation"},{"id":"4674ad0c-1a81-4e0a-857a-04d00e521b05","type":"GlyphRenderer"},{"id":"7ad58cc4-b0d6-4b56-a893-c0e9373c6b43","type":"GlyphRenderer"},{"id":"fffb7617-331a-4eb6-a7bd-c51b4283b9ce","type":"GlyphRenderer"},{"id":"b0b32f05-759c-4106-ad2a-65f50273638b","type":"GlyphRenderer"},{"id":"38072056-1990-4753-89ce-8871dc4624f6","type":"GlyphRenderer"},{"id":"428e986f-0d12-4032-8a15-633e5ab0338f","type":"GlyphRenderer"},{"id":"961c4751-5b70-4e09-af93-36ad34ba201e","type":"CategoricalAxis"},{"id":"f8296dd8-3265-4964-859b-4dd818a95ea5","type":"LinearAxis"},{"id":"026cd430-1b7b-408c-a2c9-2b7352f302d7","type":"Grid"}],"title":{"id":"5b5f1a85-c7d6-4464-b2c0-4b68605550a0","type":"Title"},"tool_events":{"id":"027e040a-45ea-426f-9a3d-107e49f2f8c4","type":"ToolEvents"},"toolbar":{"id":"8659d303-39bd-4454-9782-b00cf303be2a","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"055f47f1-31d0-4efb-a4a6-95ce1544be38","type":"FactorRange"},"y_mapper_type":"auto","y_range":{"id":"59905e34-855b-4f21-8089-9bb914042baa","type":"Range1d"}},"id":"caafd0ab-0b43-47dd-b618-f3c7b39b5e61","subtype":"Chart","type":"Plot"},{"attributes":{"axis_label":"N\u00ba de Reprovados","formatter":{"id":"3507bbfa-2bc6-4cb5-9dda-fde5d8c1a4a7","type":"BasicTickFormatter"},"plot":{"id":"caafd0ab-0b43-47dd-b618-f3c7b39b5e61","subtype":"Chart","type":"Plot"},"ticker":{"id":"92983c36-2ec1-42c3-ba62-09e407df1072","type":"BasicTicker"}},"id":"f8296dd8-3265-4964-859b-4dd818a95ea5","type":"LinearAxis"},{"attributes":{"plot":null,"text":"Disciplinas pelo N\u00ba de Reprovados"},"id":"5b5f1a85-c7d6-4464-b2c0-4b68605550a0","type":"Title"},{"attributes":{},"id":"92983c36-2ec1-42c3-ba62-09e407df1072","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"caafd0ab-0b43-47dd-b618-f3c7b39b5e61","subtype":"Chart","type":"Plot"},"ticker":{"id":"92983c36-2ec1-42c3-ba62-09e407df1072","type":"BasicTicker"}},"id":"026cd430-1b7b-408c-a2c9-2b7352f302d7","type":"Grid"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"34097b9d-add5-447d-91fd-933534c08c43","type":"BoxZoomTool"},{"id":"c50c0ace-4b69-4f1b-8bf5-ed5c417d816d","type":"BoxSelectTool"},{"id":"68f2ab73-c48a-4b35-964e-a7f7aa75938d","type":"CrosshairTool"},{"id":"7f50eaf5-7d3b-4b46-972c-fc961f1801e9","type":"ResizeTool"},{"id":"82e8f0a5-ad2f-4adf-93a0-be539c9e436e","type":"ResetTool"},{"id":"fd4de221-5269-43e8-9baf-491b32be5971","type":"WheelZoomTool"},{"id":"e8496eb9-6cbb-4809-9e52-748a9a5038eb","type":"PanTool"}]},"id":"8659d303-39bd-4454-9782-b00cf303be2a","type":"Toolbar"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"3c870678-6972-419d-b815-b024ae062d8d","type":"BoxAnnotation"},{"attributes":{"overlay":{"id":"3c870678-6972-419d-b815-b024ae062d8d","type":"BoxAnnotation"},"plot":{"id":"caafd0ab-0b43-47dd-b618-f3c7b39b5e61","subtype":"Chart","type":"Plot"}},"id":"34097b9d-add5-447d-91fd-933534c08c43","type":"BoxZoomTool"},{"attributes":{"callback":null,"overlay":{"id":"71f616b0-f2fd-420a-b2aa-796edebd159f","type":"BoxAnnotation"},"plot":{"id":"caafd0ab-0b43-47dd-b618-f3c7b39b5e61","subtype":"Chart","type":"Plot"}},"id":"c50c0ace-4b69-4f1b-8bf5-ed5c417d816d","type":"BoxSelectTool"},{"attributes":{"plot":{"id":"caafd0ab-0b43-47dd-b618-f3c7b39b5e61","subtype":"Chart","type":"Plot"}},"id":"6 ...

# %%
data_2 = pd.read_sql_query("select * from Grade",engine)
dataYear2014_nota1 = data_2[data_2["Período"] == 2014.1]
dataYear2015_nota1 = data_2[data_2["Período"] == 2015.1]
dataYear2016_nota1 = data_2[data_2["Período"] == 2016.1]
dataYear2014_nota2 = data_2[data_2["Período"] == 2014.2]
dataYear2015_nota2 = data_2[data_2["Período"] == 2015.2]
dataYear2016_nota2 = data_2[data_2["Período"] == 2016.2]


NotasYear2014_1 = BoxPlot(dataYear2014_nota1, values='Média Final', label='Disciplina', color = 'Disciplina', legend = False, 
             title = "BoxPlot das disciplinas pelas notas, Ano 2014.1", tools = [TOOLS])

NotasYear2015_1 = BoxPlot(dataYear2015_nota1, values='Média Final', label='Disciplina', color = 'Disciplina',legend = False,
            title = "BoxPlot das disciplinas pelas notas, Ano 2015.1", tools = [TOOLS])

NotasYear2016_1 = BoxPlot(dataYear2016_nota1, values='Média Final', label='Disciplina', color = 'Disciplina',legend = False,
            title = "BoxPlot das disciplinas pelas notas, Ano 2016.1", tools = [TOOLS])

NotasYear2014_2 = BoxPlot(dataYear2014_nota2, values='Média Final', label='Disciplina', color = 'Disciplina', legend = False, 
             title = "BoxPlot das disciplinas pelas notas, Ano 2014", tools = [TOOLS])

NotasYear2015_2 = BoxPlot(dataYear2015_nota2, values='Média Final', label='Disciplina', color = 'Disciplina',legend = False,
            title = "BoxPlot das disciplinas pelas notas, Ano 2015.1", tools = [TOOLS])

NotasYear2016_2 = BoxPlot(dataYear2016_nota2, values='Média Final', label='Disciplina', color = 'Disciplina',legend = False,
            title = "BoxPlot das disciplinas pelas notas, Ano 2016.1", tools = [TOOLS])

# %% [markdown]
# ## Análise 2 - Disciplinas x Notas em cada ano.
#
# Nesta seção utilizamos os dados de cada uma das disciplinas pelas notas, em cada ano em que foram ofertadas.
#
# Analisando as disciplinas, a grande maioria delas se mantém no mesmo nível ao longo dos períodos. Um destaque para essa análise é ofato de que as medianas estão sempre próximas de 5 e 6, o que podemos concluir que em algumas disciplinas, como EDBI e LPI, a maioria dos alunos ou está sendo reprovada ou passando com dificudade. Também podemos notar a disciplina de LPI que no ano de 2016 teve sua mediana menor que os anos anteriores, na qual no ano de 2016, cerca de $50\%$ dos alunos ficaram com média bem próximos a 5 e mediana da turma aproximadamente 3,2.

# %%
row1 = [NotasYear2014_1,NotasYear2014_2]

# Create a list containing plots p3 and p4: row2
row2 = [NotasYear2015_1,NotasYear2015_2]

row3 = [NotasYear2016_1,NotasYear2016_2]

# Create a gridplot using row1 and row2: layout
layout = gridplot([row1,row2,row3],plot_width=480, plot_height=700)

output_notebook()


show(layout)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="aaadfd2f-e33a-4c6e-b975-ee7b0c01f631">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="21d38ef1-d190-4b30-92a9-534f6ea0357e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("21d38ef1-d190-4b30-92a9-534f6ea0357e").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("21d38ef1-d190-4b30-92a9-534f6ea0357e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '21d38ef1-d190-4b30-92a9-534f6ea0357e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"3e745f9a-5275-4488-811b-5756f149cf23":{"roots":{"references":[{"attributes":{"line_width":{"value":2},"x0":{"field":"x0s"},"x1":{"field":"x1s"},"y0":{"field":"y0s"},"y1":{"field":"y1s"}},"id":"f9a2bc35-f42c-45cc-a3fc-1757b34bc745","type":"Segment"},{"attributes":{"line_width":{"value":2},"x0":{"field":"x0s"},"x1":{"field":"x1s"},"y0":{"field":"y0s"},"y1":{"field":"y1s"}},"id":"afde9cf3-4ecf-4c7a-a0c2-3a24b2f42607","type":"Segment"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"Disciplina":["IMD0030 - LINGUAGEM DE PROGRAMA\u00c7\u0102O I"],"chart_index":[{"Disciplina":"IMD0030 - LINGUAGEM DE PROGRAMA\u00c7\u0102O I"}],"color":["#df5320"],"fill_alpha":[0.8],"height":[4.5],"label":[{"Disciplina":"IMD0030 - LINGUAGEM DE PROGRAMA\u00c7\u0102O I"}],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["IMD0030 - LINGUAGEM DE PROGRAMA\u00c7\u0102O I"],"y":[2.75]}},"id":"9e1df9e1-4f7b-4bb1-93b4-05a944383bf1","type":"ColumnDataSource"},{"attributes":{"line_width":{"value":2},"x0":{"field":"x0s"},"x1":{"field":"x1s"},"y0":{"field":"y0s"},"y1":{"field":"y1s"}},"id":"216b885e-52bd-4f0b-b7af-dd2a9762b6e2","type":"Segment"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"06e1afb0-c1cf-41f8-847c-4ae3a9f33c37","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"8fcd75d0-f091-4c4e-82b9-e9743f568762","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"Disciplina":["IMD0030 - LINGUAGEM DE PROGRAMA\u00c7\u0102O I"],"chart_index":[{"Disciplina":"IMD0030 - LINGUAGEM DE PROGRAMA\u00c7\u0102O I"}],"color":["#df5320"],"fill_alpha":[0.8],"height":[2.0749999999999993],"label":[{"Disciplina":"IMD0030 - LINGUAGEM DE PROGRAMA\u00c7\u0102O I"}],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["IMD0030 - LINGUAGEM DE PROGRAMA\u00c7\u0102O I"],"y":[6.0375]}},"id":"3f02ff2a-d679-4eee-9795-0755a36dd139","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"a4f52187-316b-4018-a789-dd9bcd96eead","type":"ColumnDataSource"},"glyph":{"id":"f9a2bc35-f42c-45cc-a3fc-1757b34bc745","type":"Segment"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"4d95af30-ef58-4ec8-960f-17e8bd4bf7c7","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"Disciplina":["IMD0039 - ESTRUTURAS DE DADOS B\u00c1SICAS II"],"chart_index":[{"Disciplina":"IMD0039 - ESTRUTURAS DE DADOS B\u00c1SICAS II"}],"color":["#00ad9c"],"fill_alpha":[0.8],"height":[1.0],"label":[{"Disciplina":"IMD0039 - ESTRUTURAS DE DADOS B\u00c1SICAS II"}],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["IMD0039 - ESTRUTURAS DE DADOS B\u00c1SICAS II"],"y":[5.5]}},"id":"21ceb842-23f1-40b7-987d-c6da3d5d6d9f","type":"ColumnDataSource"},{"attributes":{},"id":"5aa6dd21-0044-469b-826c-7791c5c27a39","type":"ToolEvents"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"fd4abcba-b3c1-4d72-8c16-14ff89e90ee8","type":"Rect"},{"attributes":{"data_source":{"id":"7ce5d608-c6fe-4b80-8b96-5f92deddb2f2","type":"ColumnDataSource"},"glyph":{"id":"216b885e-52bd-4f0b-b7af-dd2a9762b6e2","type":"Segment"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null}, ...

# %% [markdown]
# ## Análise 3 - Disciplinas x Notas em todos os anos.
#
# Nesta seção utilizamos os dados de cada uma das disciplinas pelas notas, em cada ano em que foram ofertadas.
#
# Analisando as disciplinas, como dito anteriormente, no geral, as notas estão com medianas entre 5 e 6. As disciplinas iniciais ITP, PTP, EDBI e LP1, possuem uma distribuição menos concentra em relação a EDII e LPII. Destque LP2 com mais de $50\%$ da turma acima de 5.2 e com as melhores notas, levando em consideração as disciplinas de programação.

# %%
BoxPlot_Nota = BoxPlot(data_2, values='Média Final', label='Disciplina', legend = False, color = 'Disciplina', tools = [TOOLS])

output_notebook()


show(BoxPlot_Nota)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1cba8d45-b3d2-4277-b587-72c0537ddb19">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="895f5b5a-67a7-42e7-bbf9-9112ee513633"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("895f5b5a-67a7-42e7-bbf9-9112ee513633").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("895f5b5a-67a7-42e7-bbf9-9112ee513633");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '895f5b5a-67a7-42e7-bbf9-9112ee513633' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6d2732a3-db0e-4d53-82e1-a29b778f2cd8":{"roots":{"references":[{"attributes":{"data_source":{"id":"90fa8521-d6db-4db1-9a11-c098f67b151f","type":"ColumnDataSource"},"glyph":{"id":"e5dc151c-f150-46ad-8a0d-ec1ae4dc2c11","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"cc005576-662c-4a92-bbdd-f770d46c518f","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"cf5490c1-2897-4e50-a308-b27e8084f3c6","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"Disciplina":["IMD0030 - LINGUAGEM DE PROGRAMA\u00c7\u0102O I"],"chart_index":[{"Disciplina":"IMD0030 - LINGUAGEM DE PROGRAMA\u00c7\u0102O I"}],"color":["#df5320"],"fill_alpha":[0.8],"height":[3.6],"label":[{"Disciplina":"IMD0030 - LINGUAGEM DE PROGRAMA\u00c7\u0102O I"}],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["IMD0030 - LINGUAGEM DE PROGRAMA\u00c7\u0102O I"],"y":[3.2]}},"id":"5cef0da7-f53e-4682-ba19-6927feee6b15","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"58d7c555-4f97-4b4e-92a7-83d7be256509","type":"Rect"},{"attributes":{"data_source":{"id":"5cef0da7-f53e-4682-ba19-6927feee6b15","type":"ColumnDataSource"},"glyph":{"id":"cf5490c1-2897-4e50-a308-b27e8084f3c6","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"f529c9ec-983f-4842-a1b2-c2be89fa70f9","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"Disciplina":["IMD0040 - LINGUAGEM DE PROGRAMA\u00c7\u0102O II"],"chart_index":[{"Disciplina":"IMD0040 - LINGUAGEM DE PROGRAMA\u00c7\u0102O II"}],"color":["#c33ff3"],"fill_alpha":[0.8],"height":[1.0499999999999998],"label":[{"Disciplina":"IMD0040 - LINGUAGEM DE PROGRAMA\u00c7\u0102O II"}],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["IMD0040 - LINGUAGEM DE PROGRAMA\u00c7\u0102O II"],"y":[7.025]}},"id":"8b76d676-96bd-4026-870d-809266154e1d","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"94292b42-05d2-45e8-b83c-7bf9a0162024","type":"Rect"},{"attributes":{"data_source":{"id":"8b76d676-96bd-4026-870d-809266154e1d","type":"ColumnDataSource"},"glyph":{"id":"94292b42-05d2-45e8-b83c-7bf9a0162024","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"b0aee893-5968-4dcb-9977-c9bd1d8b69f4","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x0s","y0s","x1s","y1s"],"data":{"Disciplina":["IMD0030 - LINGUAGEM DE PROGRAMA\u00c7\u0102O I","IMD0030 - LINGUAGEM DE PROGRAMA\u00c7\u0102O I","IMD0030 - LINGUAGEM DE PROGRAMA\u00c7\u0102O I","IMD0030 - LINGUAGEM DE PROGRAMA\u00c7\u0102O I"],"chart_index":[{"Disciplina":"IMD0030 - LINGUAGEM DE PROGRAMA\u00c7\u0102O I"},{"Disciplina":"IMD0030 - LINGUAGEM DE PROGRAMA\u00c7\u0102O I"},{"Disciplina":"IMD0030 - LINGUAGEM DE PROGRAMA\u00c7\u0102O I"},{"Disciplina":"IMD0030 - LINGUAGEM DE PROGRAMA\u00c7\u0102O I"}],"x0s":["IMD0030 - LINGUAGEM DE PROGRAMA\u00c7\u0102O I:0.5","IMD0030 - LINGUAGEM DE PROGRAMA\u00c7\u0102O I:0.65","IMD0030 - LINGUAGEM DE PROGRAMA\u00c7\u0102O I:0.5","IMD0030 - LINGUAGEM DE PROGRAMA\u00c7\u0102O I:0.65"],"x1s":["IMD0030 - LINGUAGEM DE PROGRAMA\u00c7\u0102O I:0.5","IMD0030 - LINGUAGEM DE PR ...
